# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd
import dash_leaflet as dl

df = pd.read_csv(
    '../../Data/data_fix_temp.txt')
    
pd.set_option.max_rows = 50

app = Dash(__name__)

app.layout = html.Div([
    dl.Map(
        [
            dl.TileLayer(),
            dl.Marker(
                position=[51.51, -0.12],
                children=[
                    dl.Tooltip(dcc.Graph(
                        id='graph-content',
                        style={
                            'width': '200px',  # Adjust the width as needed
                            'height': '150px',  # Adjust the height as needed
                        }
                    ))
                ]
            )
        ],
        center=[51.51, -0.12],
        zoom=10
    )
])


if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from dash import Dash
import dash_leaflet as dl

app = Dash()
app.layout = dl.Map(dl.TileLayer(), center=[6.19,106.82], zoom=6, style={'height': '50vh'})

if __name__ == '__main__':
    app.run_server()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Import packages
from dash import Dash, html, dash_table
import pandas as pd

# Incorporate data
df_temp = pd.read_csv('../../Data/data_fix_temp.txt')
df_wmoid = pd.read_excel('../../Data/daftar_wmoid.xlsx')

# Initialize the app
app = Dash(__name__)

# App layout
app.layout = html.Div([
    html.Div(children='My First App with Data'),
    # dash_table.DataTable(data=df_temp.to_dict('records'), page_size=10),
    dash_table.DataTable(data=df_wmoid.to_dict('records'), page_size=10)
])

# Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.to_dict('records')
# Out:
# [{'Date': '2021-02-27 15:00:00',
#   'lokasi': 96001,
#   'con_prec.mm.': 0.0,
#   'mic_prec.mm.': 0.0,
#   'sha_prec.mm.': 0,
#   'suhu2m.degC.': 27.3973,
#   'dew2m.degC.': 21.6059,
#   'rh2m...': 70.8014,
#   'wspeed.m.s.': 3.43326,
#   'wdir.deg.': 12.458,
#   'lcloud...': 0.553781,
#   'mcloud...': 0.0,
#   'hcloud...': 0.0,
#   'surpre.Pa.': 100564.0,
#   'clmix.kg.kg.': 0.0,
#   'wamix.kg.kg.': 0.0149855,
#   'outlr.W.m2.': 299.737,
#   'pblh.m.': 770.659,
#   'lifcl.m.': 908.41,
#   'cape.j.kg.': 38.5747,
#   'mdbz': 0.0,
#   't950.degC.': 22.3437,
#   'rh950...': 81.3926,
#   'ws950.m.s.': 3.51896,
#   'wd950.deg.': 12.6254,
#   't800.degC.': 17.0906,
#   'rh800...': 20.4601,
#   'ws800.m.s.': 0.76722,
#   'wd800.deg.': 281.622,
#   't500.degC.': -5.2089,
#   'rh500...': 11.0889,
#   'ws500.m.s.': 6.22327,
#   'wd500.deg.': 57.5841,
#   'hari': 0,
#   'UTC': 12,
#   'LAT': 5.87655,
#   'LON': 95.33785,
#   'ELEV': 126,
#   't_obs': 23.2},
#  {'Date': '2021-02-27 18:00:00',
# ...

# %%
import netCDF4 as nc

# %%
url = 'http://182.16.248.173:8080/dods/INA-NWP/2023101712/2023101712-d02-asim'
nc_data = nc.Dataset(url)
nc_data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     comment: TITLE =  OUTPUT FROM WRF V4.2 MODEL
# START_DATE = 2023-10-17_12:00:00
# SIMULATION_START_DATE = 2023-10-17_12:00:00
# WEST-EAST_GRID_DIMENSION =   607
# SOUTH-NORTH_GRID_DIMENSION =   298
# BOTTOM-TOP_GRID_DIMENSION =    33
# DX =      3000.00
# DY =      3000.00
# AERCU_OPT =     0
# AERCU_FCT =         1.00
# IDEAL_CASE =     0
# DIFF_6TH_SLOPEOPT =     0
# AUTO_LEVELS_OPT =     2
# DIFF_6TH_THRESH =         0.10
# DZBOT =        50.00
# DZSTRETCH_S =         1.30
# DZSTRETCH_U =         1.10
# SKEBS_ON =     0
# SPEC_BDY_FINAL_MU =     1
# USE_Q_DIABATIC =     0
# GRIDTYPE = C
# DIFF_OPT =     1
# KM_OPT =     4
# DAMP_OPT =     0
# DAMPCOEF =         0.20
# KHDIF =         0.00
# KVDIF =         0.00
# MP_PHYSICS =     6
# RA_LW_PHYSICS =     4
# RA_SW_PHYSICS =     4
# SF_SFCLAY_PHYSICS =    91
# SF_SURFACE_PHYSICS =     2
# BL_PBL_PHYSICS =     5
# CU_PHYSICS =    16
# ...

# %%
(nc_data.variables.keys() )
# Out:
# dict_keys(['time', 'lev', 'lat', 'lon', 'xlat', 'xlong', 'lu_index', 'var_sso', 'u', 'v', 'w', 'ph', 'phb', 't', 'thm', 'mu', 'mub', 'nest_pos', 'p', 'pb', 'p_hyd', 'q2', 't2', 'th2', 'psfc', 'u10', 'v10', 'area2d', 'dx2d', 'qvapor', 'qcloud', 'qrain', 'qice', 'qsnow', 'qgraup', 'shdmax', 'shdmin', 'snoalb', 'tslb', 'smois', 'sh2o', 'smcrel', 'seaice', 'xicem', 'sfroff', 'udroff', 'ivgtyp', 'isltyp', 'vegfra', 'sfcevp', 'grdflx', 'acgrdflx', 'acsnom', 'snow', 'snowh', 'canwat', 'sstsk', 'coszen', 'lai', 'var', 'tke_pbl', 'el_pbl', 'mapfac_m', 'mapfac_mx', 'mapfac_my', 'mf_vx_inv', 'f', 'e', 'sinalpha', 'cosalpha', 'hgt', 'tsk', 'rainc', 'rainsh', 'rainnc', 'snownc', 'graupelnc', 'hailnc', 'refl_10cm', 'cldfra', 'swdown', 'swdownc', 'glw', 'swnorm', 'swddir', 'swddni', 'swddnic', 'swddif', 'olr', 'albedo', 'clat', 'albbck', 'emiss', 'noahres', 'tmn', 'xland', 'ust', 'pblh', 'hfx', 'qfx', 'lh', 'achfx', 'aclhf', 'snowc', 'sr', 'potevp', 'wspd10max', 'refd_max', 'up_heli_ma', 'afwa_llws
# ...

# %%
temperature = nc_data.variables['tc']
temperature
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 tc(time, lev, lat, lon)
#     _FillValue: 1e+30
#     missing_value: 1e+30
#     long_name: temperature (c)
# unlimited dimensions:
# current shape = (25, 19, 297, 606)
# filling off

# %%
print(temperature.dimensions)
print(temperature.shape)
# Out:
# ('time', 'lev', 'lat', 'lon')
# (25, 19, 297, 606)

# %%
for d in nc_data.dimensions.items():
  print(d)
# Out:
# ('lat', <class 'netCDF4._netCDF4.Dimension'>: name = 'lat', size = 297)
# ('lev', <class 'netCDF4._netCDF4.Dimension'>: name = 'lev', size = 19)
# ('lon', <class 'netCDF4._netCDF4.Dimension'>: name = 'lon', size = 606)
# ('time', <class 'netCDF4._netCDF4.Dimension'>: name = 'time', size = 25)

# %%
test_lon = nc_data.variables['lon']
test_lon
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lon(lon)
#     grads_dim: x
#     grads_mapping: levels
#     grads_size: 606
#     units: degrees_east
#     long_name: longitude
#     minimum: 101.648895
#     maximum: 117.991135
#     resolution: 0.027011966
# unlimited dimensions:
# current shape = (606,)
# filling off

# %%
test_lat = nc_data.variables['lat']
test_lat
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 lat(lat)
#     grads_dim: y
#     grads_mapping: levels
#     grads_size: 297
#     units: degrees_north
#     long_name: latitude
#     minimum: -11.0004501
#     maximum: -3.07164764
#     resolution: 0.026786495
# unlimited dimensions:
# current shape = (297,)
# filling off

# %%
print(test_lon[:])
# Out:
# [101.648895 101.675903 101.702919 101.729927 101.756943 101.783951
#  101.810966 101.837982 101.86499  101.891998 101.919014 101.94603
#  101.973038 102.000053 102.027061 102.054077 102.081085 102.108101
#  102.135109 102.162125 102.189133 102.216148 102.243156 102.270172
#  102.29718  102.324196 102.351204 102.37822  102.405228 102.432243
#  102.459251 102.486267 102.513275 102.540291 102.567299 102.594315
#  102.621323 102.648338 102.675346 102.702362 102.72937  102.756386
#  102.783394 102.81041  102.837418 102.864433 102.891449 102.918457
#  102.945473 102.972481 102.999496 103.026505 103.05352  103.080528
#  103.107544 103.134552 103.161568 103.188576 103.215591 103.242599
#  103.269615 103.296623 103.323639 103.350647 103.377663 103.404671
#  103.431686 103.458694 103.48571  103.512718 103.539734 103.566742
#  103.593758 103.620766 103.647781 103.674789 103.701805 103.728813
#  103.755829 103.782837 103.809853 103.836868 103.863876 103.890884
# ...

# %%
print(test_lat[:])
# Out:
# [-11.0004501  -10.973938   -10.9474182  -10.9208908  -10.894371
#  -10.8678436  -10.8413162  -10.8147812  -10.7882538  -10.7617188
#  -10.7351837  -10.7086411  -10.6820908  -10.6555481  -10.6289978
#  -10.6024475  -10.5758972  -10.5493469  -10.522789   -10.4962311
#  -10.4696732  -10.4431076  -10.4165421  -10.3899689  -10.3634033
#  -10.3368301  -10.310257   -10.2836761  -10.2570953  -10.2305222
#  -10.2039261  -10.1773453  -10.1507568  -10.124176   -10.0975723
#  -10.0709839  -10.0443802  -10.0177841   -9.99118805  -9.96457672
#   -9.93797302  -9.91136932  -9.884758    -9.85814667  -9.83153534
#   -9.80491638  -9.77829742  -9.75167847  -9.72505188  -9.69843292
#   -9.67179871  -9.64517212  -9.6185379   -9.59191132  -9.56526947
#   -9.53863525  -9.51199341  -9.48535156  -9.45871735  -9.43206024
#   -9.4054184   -9.37876892  -9.35211182  -9.32546234  -9.29880524
#   -9.27214813  -9.24549103  -9.21882629  -9.19216156  -9.16549683
# ...

# %%
import matplotlib.pyplot as plt

# %%
for dname in temperature.dimensions:
  print(nc_data.variables[dname])
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 time(time)
#     grads_dim: t
#     grads_mapping: linear
#     grads_size: 25
#     grads_min: 12z17oct2023
#     grads_step: 180mn
#     units: days since 1-1-1 00:00:0.0
#     long_name: time
#     minimum: 12z17oct2023
#     maximum: 12z20oct2023
#     resolution: 0.125
# unlimited dimensions:
# current shape = (25,)
# filling off
# <class 'netCDF4._netCDF4.Variable'>
# float64 lev(lev)
#     grads_dim: z
#     grads_mapping: levels
#     units: millibar
#     long_name: altitude
#     minimum: 1000.0
#     maximum: 100.0
#     resolution: 50.0
# unlimited dimensions:
# current shape = (19,)
# filling off
# <class 'netCDF4._netCDF4.Variable'>
# float64 lat(lat)
#     grads_dim: y
#     grads_mapping: levels
#     grads_size: 297
#     units: degrees_north
#     long_name: latitude
#     minimum: -11.0004501
#     maximum: -3.07164764
#     resolution: 0.026786495
# unlimited dimensions:
# current shape = (297,)
# filling off
# ...

# %%
print(temperature.missing_value)
# Out:
# 1e+30

# %%
nc_data.variables['time'][:]
# Out:
# masked_array(data=[738811.5  , 738811.625, 738811.75 , 738811.875,
#                    738812.   , 738812.125, 738812.25 , 738812.375,
#                    738812.5  , 738812.625, 738812.75 , 738812.875,
#                    738813.   , 738813.125, 738813.25 , 738813.375,
#                    738813.5  , 738813.625, 738813.75 , 738813.875,
#                    738814.   , 738814.125, 738814.25 , 738814.375,
#                    738814.5  ],
#              mask=False,
#        fill_value=1e+20)

# %%
nc_data.variables
# Out:
# {'time': <class 'netCDF4._netCDF4.Variable'>
#  float64 time(time)
#      grads_dim: t
#      grads_mapping: linear
#      grads_size: 25
#      grads_min: 12z17oct2023
#      grads_step: 180mn
#      units: days since 1-1-1 00:00:0.0
#      long_name: time
#      minimum: 12z17oct2023
#      maximum: 12z20oct2023
#      resolution: 0.125
#  unlimited dimensions:
#  current shape = (25,)
#  filling off,
#  'lev': <class 'netCDF4._netCDF4.Variable'>
#  float64 lev(lev)
#      grads_dim: z
#      grads_mapping: levels
#      units: millibar
#      long_name: altitude
#      minimum: 1000.0
#      maximum: 100.0
#      resolution: 50.0
#  unlimited dimensions:
#  current shape = (19,)
#  filling off,
#  'lat': <class 'netCDF4._netCDF4.Variable'>
#  float64 lat(lat)
#      grads_dim: y
#      grads_mapping: levels
#      grads_size: 297
#      units: degrees_north
#      long_name: latitude
#      minimum: -11.0004501
#      maximum: -3.07164764
#      resolution: 0.026786495
# ...

# %%
plt.contourf

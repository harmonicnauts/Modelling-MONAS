# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df_temperatur = pd.read_csv('C:/Users/Nycht/Documents/Programming/Project/MONAS Dashboard/Modelling/data_fix_temp.txt')
df_temperatur.head(10)
df_temperatur = df_temperatur.tail(1000)
df_temperatur = df_temperatur.set_index('Date')

# %%
df_temperatur.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2022-03-23 06:00:00 to 2023-04-13 00:00:00
# Data columns (total 38 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lokasi        1000 non-null   int64
#  1   con_prec.mm.  1000 non-null   float64
#  2   mic_prec.mm.  1000 non-null   float64
#  3   sha_prec.mm.  1000 non-null   int64
#  4   suhu2m.degC.  1000 non-null   float64
#  5   dew2m.degC.   1000 non-null   float64
#  6   rh2m...       1000 non-null   float64
#  7   wspeed.m.s.   1000 non-null   float64
#  8   wdir.deg.     1000 non-null   float64
#  9   lcloud...     1000 non-null   float64
#  10  mcloud...     1000 non-null   float64
#  11  hcloud...     1000 non-null   float64
#  12  surpre.Pa.    1000 non-null   float64
#  13  clmix.kg.kg.  1000 non-null   float64
#  14  wamix.kg.kg.  1000 non-null   float64
#  15  outlr.W.m2.   1000 non-null   float64
#  16  pblh.m.       1000 non-null   float64
#  17  lifcl.m.      1000 non-null   float64
#  18  cape.j.kg.    1000 non-null   float64
#  19  mdbz          1000 non-null   float64
#  20  t950.degC.    1000 non-null   float64
#  21  rh950...      1000 non-null   float64
#  22  ws950.m.s.    1000 non-null   float64
#  23  wd950.deg.    1000 non-null   float64
#  24  t800.degC.    1000 non-null   float64
#  25  rh800...      1000 non-null   float64
#  26  ws800.m.s.    1000 non-null   float64
#  27  wd800.deg.    1000 non-null   float64
#  28  t500.degC.    1000 non-null   float64
#  29  rh500...      1000 non-null   float64
#  30  ws500.m.s.    1000 non-null   float64
#  31  wd500.deg.    1000 non-null   float64
#  32  hari          1000 non-null   int64
#  33  UTC           1000 non-null   int64
#  34  LAT           1000 non-null   float64
#  35  LON           1000 non-null   float64
#  36  ELEV          1000 non-null   int64
#  37  t_obs         1000 non-null   float64
# dtypes: float64(33), int64(5)
# memory usage: 304.7+ KB

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data = df_temperatur.tail(1000), x='Date', y='t_obs')
# Out:
# <Axes: xlabel='Date', ylabel='t_obs'>

# %%
df_temperatur.describe()
# Out:
#         lokasi  con_prec.mm.  mic_prec.mm.  sha_prec.mm.  suhu2m.degC.  \
# count   1000.0   1000.000000  1.000000e+03        1000.0   1000.000000
# mean   99992.0      1.028963  2.134116e-01           0.0     28.145335
# std        0.0      2.060812  2.126447e+00           0.0      2.479020
# min    99992.0      0.000000  0.000000e+00           0.0     23.134500
# 25%    99992.0      0.000000  0.000000e+00           0.0     25.745200
# 50%    99992.0      0.087199  0.000000e+00           0.0     28.602000
# 75%    99992.0      1.003803  7.512225e-20           0.0     30.191175
# max    99992.0     17.722800  4.426580e+01           0.0     33.384900
#
#        dew2m.degC.      rh2m...  wspeed.m.s.    wdir.deg.    lcloud...  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     22.840965    74.184812     2.646446   204.572267     0.557904  ...
# std       1.276479    12.240464     1.560071   105.443742     0.272491  ...
# min      16.955300    40.180500     0.102948     0.701538     0.000000  ...
# 25%      22.114775    65.224125     1.488325   114.059000     0.374799  ...
# 50%      23.050950    73.709500     2.420005   240.816000     0.582077  ...
# 75%      23.757300    84.462450     3.599010   284.830500     0.775674  ...
# max      25.453600    98.623600     8.345900   359.968000     1.000000  ...
#
#         t500.degC.     rh500...   ws500.m.s.   wd500.deg.         hari  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -4.973697    62.814302     5.440421   151.799815     0.315000
# std       0.625306    19.786087     2.887955    95.943822     0.464748
# min      -7.075940     0.511116     0.165846     4.742930     0.000000
# 25%      -5.390273    50.831650     3.328025    77.913450     0.000000
# 50%      -4.978005    66.126350     4.964985   105.112500     0.000000
# 75%      -4.551520    77.838325     7.153588   253.093500     1.000000
# max      -3.146340    98.936000    18.426700   355.015000     1.000000
#
#           UTC           LAT           LON    ELEV        t_obs
# count  1000.0  1.000000e+03  1.000000e+03  1000.0  1000.000000
# mean     12.0 -6.302530e+00  1.067564e+02    41.0    29.158300
# std       0.0  5.242875e-14  1.336489e-12     0.0     3.164994
# min      12.0 -6.302530e+00  1.067564e+02    41.0    23.000000
# 25%      12.0 -6.302530e+00  1.067564e+02    41.0    26.000000
# 50%      12.0 -6.302530e+00  1.067564e+02    41.0    29.400000
# 75%      12.0 -6.302530e+00  1.067564e+02    41.0    32.000000
# max      12.0 -6.302530e+00  1.067564e+02    41.0    36.000000
#
# [8 rows x 38 columns]

# %%
# split data
train_size = int(len(df_temperatur) * 0.7) # Menentukan banyaknya data train yaitu sebesar 70% data
train = df_temperatur[:train_size]
test = df_temperatur[train_size:].reset_index(drop=True)

# %%
test
# Out:
#      lokasi  con_prec.mm.  mic_prec.mm.  sha_prec.mm.  suhu2m.degC.  \
# 0     99992      4.309790  9.046390e-02             0       29.4541
# 1     99992      0.122591  0.000000e+00             0       26.6707
# 2     99992      0.036089  0.000000e+00             0       25.5346
# 3     99992      0.007826  0.000000e+00             0       26.1921
# 4     99992      0.145046  0.000000e+00             0       29.7982
# ..      ...           ...           ...           ...           ...
# 295   99992      0.003601  0.000000e+00             0       29.7642
# 296   99992      3.669660  7.573590e-21             0       30.7901
# 297   99992      4.045040  2.640270e-09             0       28.8450
# 298   99992      0.000000  0.000000e+00             0       25.8334
# 299   99992      0.000000  0.000000e+00             0       24.5158
#
#      dew2m.degC.  rh2m...  wspeed.m.s.  wdir.deg.  lcloud...  ...  t500.degC.  \
# 0        23.6252  71.0024     3.708880    317.846   0.657009  ...    -4.83942
# 1        24.4271  87.6409     3.226950    322.756   0.261674  ...    -4.96670
# 2        23.6743  89.5972     0.684874    215.947   0.849919  ...    -5.48644
# 3        23.0959  83.2163     0.504557    214.238   0.689163  ...    -5.23281
# 4        22.7791  66.1390     1.907670    295.236   0.434788  ...    -4.88066
# ..           ...      ...          ...        ...        ...  ...         ...
# 295      23.4001  68.8035     3.721340    261.504   0.390150  ...    -4.69787
#
#                      wdir.deg.  lcloud...  ...  t500.degC.  rh500...  \
# Date                                       ...
# 2022-03-23 06:00:00    263.136   0.535150  ...    -4.83292   75.8759
# 2022-03-23 09:00:00    259.473   0.368339  ...    -4.64097   74.5520
# 2022-03-23 12:00:00    264.010   0.240056  ...    -4.55134   68.8819
# 2022-03-24 00:00:00    203.962   0.630413  ...    -5.28989   63.2051
# 2022-03-25 00:00:00    177.881   0.378047  ...    -6.00165   69.3229
# ...                        ...        ...  ...         ...       ...
# 2022-12-12 06:00:00    346.729   0.689661  ...    -5.02288   39.5054
# 2022-12-12 09:00:00    342.770   0.839974  ...    -4.85771   48.9321
# 2022-12-18 00:00:00    192.307   0.236950  ...    -5.33533   54.7129
# 2022-12-18 03:00:00    265.208   0.641065  ...    -5.16554   46.2080
# 2022-12-18 06:00:00    318.935   0.671669  ...    -4.75111   48.4516
#
#                      ws500.m.s.  wd500.deg.  hari  UTC      LAT       LON  \
# Date
# 2022-03-23 06:00:00     3.68167     99.3595     0   12 -6.30253  106.7564
# 2022-03-23 09:00:00     3.82355    338.1780     0   12 -6.30253  106.7564
# 2022-03-23 12:00:00     3.67762     73.7795     1   12 -6.30253  106.7564
# 2022-03-24 00:00:00     6.68406    321.5550     1   12 -6.30253  106.7564
# 2022-03-25 00:00:00     3.66500    324.2410     0   12 -6.30253  106.7564
# ...                         ...         ...   ...  ...      ...       ...
# 2022-12-12 06:00:00     3.11092     62.2931     1   12 -6.30253  106.7564
# 2022-12-12 09:00:00     3.67602     91.1529     1   12 -6.30253  106.7564
# 2022-12-18 00:00:00     2.81751    200.6340     0   12 -6.30253  106.7564
# 2022-12-18 03:00:00     3.04614    198.9370     0   12 -6.30253  106.7564
# 2022-12-18 06:00:00     3.62244    216.8430     0   12 -6.30253  106.7564
#
#                      ELEV  t_obs
# Date
# 2022-03-23 06:00:00    41   28.2
# 2022-03-23 09:00:00    41   29.6
# 2022-03-23 12:00:00    41   26.8
# 2022-03-24 00:00:00    41   25.2
# 2022-03-25 00:00:00    41   25.1
# ...                   ...    ...
# 2022-12-12 06:00:00    41   33.0
# 2022-12-12 09:00:00    41   32.5
# 2022-12-18 00:00:00    41   27.0
# 2022-12-18 03:00:00    41   32.6
# 2022-12-18 06:00:00    41   35.0
#
# [700 rows x 38 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train[['t_obs']])

train['t_obs_scaled'] = scaler.transform(train[['t_obs']])
test['t_obs_scaled'] = scaler.transform(test[['t_obs']])

# %%
train.head()
# Out:
#                      lokasi  con_prec.mm.  mic_prec.mm.  sha_prec.mm.  \
# Date
# 2022-03-23 06:00:00   99992      1.469110  0.000000e+00             0
# 2022-03-23 09:00:00   99992      7.294240  1.646410e-26             0
# 2022-03-23 12:00:00   99992      0.250733  0.000000e+00             0
# 2022-03-24 00:00:00   99992      0.000000  0.000000e+00             0
# 2022-03-25 00:00:00   99992      0.000000  0.000000e+00             0
#
#                      suhu2m.degC.  dew2m.degC.  rh2m...  wspeed.m.s.  \
# Date
# 2022-03-23 06:00:00       30.7327      24.1540  68.1004      4.96566
# 2022-03-23 09:00:00       28.6949      24.7255  79.2531      5.36491
# 2022-03-23 12:00:00       26.3203      24.6041  90.4240      2.79545
# 2022-03-24 00:00:00       25.1577      22.7919  86.8756      1.96149
# 2022-03-25 00:00:00       25.0365      22.6944  86.9903      1.78799
#
#                      wdir.deg.  lcloud...  ...  rh500...  ws500.m.s.  \
# Date                                       ...
# 2022-03-23 06:00:00    263.136   0.535150  ...   75.8759     3.68167
# 2022-03-23 09:00:00    259.473   0.368339  ...   74.5520     3.82355
# 2022-03-23 12:00:00    264.010   0.240056  ...   68.8819     3.67762
# 2022-03-24 00:00:00    203.962   0.630413  ...   63.2051     6.68406
# 2022-03-25 00:00:00    177.881   0.378047  ...   69.3229     3.66500
#
#                      wd500.deg.  hari  UTC      LAT       LON  ELEV  t_obs  \
# Date
# 2022-03-23 06:00:00     99.3595     0   12 -6.30253  106.7564    41   28.2
# 2022-03-23 09:00:00    338.1780     0   12 -6.30253  106.7564    41   29.6
# 2022-03-23 12:00:00     73.7795     1   12 -6.30253  106.7564    41   26.8
# 2022-03-24 00:00:00    321.5550     1   12 -6.30253  106.7564    41   25.2
# 2022-03-25 00:00:00    324.2410     0   12 -6.30253  106.7564    41   25.1
#
#                      t_obs_scaled
# Date
# 2022-03-23 06:00:00      0.400000
# 2022-03-23 09:00:00      0.507692
# 2022-03-23 12:00:00      0.292308
# 2022-03-24 00:00:00      0.169231
# 2022-03-25 00:00:00      0.161538
#
# [5 rows x 39 columns]

# %%
def sliding_window(data, window_size):
    sub_seq, next_values = [], []
    for i in range(len(data)-window_size):
        sub_seq.append(data[i:i+window_size])
        next_values.append(data[i+window_size])
    X = np.stack(sub_seq)
    y = np.array(next_values)
    return X,y

# %%
window_size = 24

X_train, y_train = sliding_window(train[['t_obs_scaled']].values, window_size)
X_test, y_test = sliding_window(test[['t_obs_scaled']].values, window_size)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (676, 24, 1) (676, 1)
# (276, 24, 1) (276, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM #, RNN, GRU

# %%
tf. __version__
# Out:
# '2.10.0'

# %%
def create_model(LSTM_unit=64, dropout=0.2): #jika ingin menggunakan RNN atau GRU ganti LSTM dengan GRU/RNN
    # create model
    model = Sequential()
    model.add(LSTM(units=LSTM_unit, input_shape=(window_size, 1)))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])
    return model

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping
# Early Stopping
es = EarlyStopping(monitor = 'val_loss', mode = "min", patience = 5)

# create model
model = KerasRegressor(build_fn=create_model, epochs=50, validation_split=0.1, batch_size=32, callbacks=[es], verbose=10)

# define the grid search parameters
LSTM_unit = [16,32,64]
dropout=[0.1,0.2]
param_grid = dict(LSTM_unit=LSTM_unit, dropout=dropout)

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=2, cv=5, verbose=10)

# %%
grid_result = grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
